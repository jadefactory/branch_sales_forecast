# %%
import pandas as pd

# %%
df_train = pd.read_csv('./data/train.csv')
df_test = pd.read_csv('./data/test.csv')
df_submission = pd.read_csv('./data/sample_submission.csv')

# %%
df_train
# Out:
#         id  Store        Date  Temperature  Fuel_Price  Promotion1  \
# 0        1      1  05/02/2010        42.31       2.572         NaN
# 1        2      1  12/02/2010        38.51       2.548         NaN
# 2        3      1  19/02/2010        39.93       2.514         NaN
# 3        4      1  26/02/2010        46.63       2.561         NaN
# 4        5      1  05/03/2010        46.50       2.625         NaN
# ...    ...    ...         ...          ...         ...         ...
# 6250  6251     45  31/08/2012        75.09       3.867    23641.30
# 6251  6252     45  07/09/2012        75.70       3.911    11024.45
# 6252  6253     45  14/09/2012        67.87       3.948    11407.95
# 6253  6254     45  21/09/2012        65.32       4.038     8452.20
# 6254  6255     45  28/09/2012        64.88       3.997     4556.61
#
#       Promotion2  Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  \
# 0            NaN         NaN         NaN         NaN         8.106      False
# ...

# %%
df_test
# Out:
#       id  Store        Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0      1      1  05/10/2012        68.55       3.617     8077.89         NaN
# 1      2      1  12/10/2012        62.99       3.601     2086.18         NaN
# 2      3      1  19/10/2012        67.97       3.594      950.33         NaN
# 3      4      1  26/10/2012        69.16       3.506     2585.85       31.75
# 4      5      2  05/10/2012        70.27       3.617     6037.76         NaN
# ..   ...    ...         ...          ...         ...         ...         ...
# 175  176     44  26/10/2012        46.97       3.755       38.65        2.61
# 176  177     45  05/10/2012        64.89       3.985     5046.74         NaN
# 177  178     45  12/10/2012        54.47       4.000     1956.28         NaN
# 178  179     45  19/10/2012        56.47       3.969     2004.02         NaN
# 179  180     45  26/10/2012        58.85       3.882     4018.91       58.08
#
# ...

# %%
df_submission
# Out:
#       id  Weekly_Sales
# 0      1             0
# 1      2             0
# 2      3             0
# 3      4             0
# 4      5             0
# ..   ...           ...
# 175  176             0
# 176  177             0
# 177  178             0
# 178  179             0
# 179  180             0
#
# [180 rows x 2 columns]

# %% [markdown]
# ---

# %%
df_train.head()
# Out:
#    id  Store        Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0   1      1  05/02/2010        42.31       2.572         NaN         NaN
# 1   2      1  12/02/2010        38.51       2.548         NaN         NaN
# 2   3      1  19/02/2010        39.93       2.514         NaN         NaN
# 3   4      1  26/02/2010        46.63       2.561         NaN         NaN
# 4   5      1  05/03/2010        46.50       2.625         NaN         NaN
#
#    Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  Weekly_Sales
# 0         NaN         NaN         NaN         8.106      False    1643690.90
# 1         NaN         NaN         NaN         8.106       True    1641957.44
# 2         NaN         NaN         NaN         8.106      False    1611968.17
# 3         NaN         NaN         NaN         8.106      False    1409727.59
# 4         NaN         NaN         NaN         8.106      False    1554806.68

# %%
df_train.tail()
# Out:
#         id  Store        Date  Temperature  Fuel_Price  Promotion1  \
# 6250  6251     45  31/08/2012        75.09       3.867    23641.30
# 6251  6252     45  07/09/2012        75.70       3.911    11024.45
# 6252  6253     45  14/09/2012        67.87       3.948    11407.95
# 6253  6254     45  21/09/2012        65.32       4.038     8452.20
# 6254  6255     45  28/09/2012        64.88       3.997     4556.61
#
#       Promotion2  Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  \
# 6250        6.00       92.93     6988.31     3992.13         8.684      False
# 6251       12.80       52.63     1854.77     2055.70         8.684       True
# 6252         NaN        4.30     3421.72     5268.92         8.684      False
# 6253       92.28       63.24     2376.38     8670.40         8.684      False
# 6254       20.64        1.50     1601.01     3288.25         8.684      False
#
#       Weekly_Sales
# 6250     734297.87
# 6251     766512.66
# 6252     702238.27
# ...

# %%
print('df_train', df_train.shape)
# Out:
# df_train (6255, 13)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6255 entries, 0 to 6254
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            6255 non-null   int64
#  1   Store         6255 non-null   int64
#  2   Date          6255 non-null   object
#  3   Temperature   6255 non-null   float64
#  4   Fuel_Price    6255 non-null   float64
#  5   Promotion1    2102 non-null   float64
#  6   Promotion2    1592 non-null   float64
#  7   Promotion3    1885 non-null   float64
#  8   Promotion4    1819 non-null   float64
#  9   Promotion5    2115 non-null   float64
#  10  Unemployment  6255 non-null   float64
#  11  IsHoliday     6255 non-null   bool
#  12  Weekly_Sales  6255 non-null   float64
# dtypes: bool(1), float64(9), int64(2), object(1)
# memory usage: 592.6+ KB

# %%
print(df_train.isnull().sum())
# Out:
# id                 0
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# Promotion1      4153
# Promotion2      4663
# Promotion3      4370
# Promotion4      4436
# Promotion5      4140
# Unemployment       0
# IsHoliday          0
# Weekly_Sales       0
# dtype: int64

# %%
print(df_test.isnull().sum())
# Out:
# id                0
# Store             0
# Date              0
# Temperature       0
# Fuel_Price        0
# Promotion1        2
# Promotion2      135
# Promotion3       19
# Promotion4       34
# Promotion5        0
# Unemployment      0
# IsHoliday         0
# dtype: int64

# %%
df_train.describe()
# Out:
#                 id        Store  Temperature   Fuel_Price    Promotion1  \
# count  6255.000000  6255.000000  6255.000000  6255.000000   2102.000000
# mean   3128.000000    23.000000    60.639199     3.344369   7155.930661
# std    1805.807299    12.988211    18.624094     0.455364   8408.206085
# min       1.000000     1.000000    -2.060000     2.472000      0.270000
# 25%    1564.500000    12.000000    47.170000     2.917000   1844.295000
# 50%    3128.000000    23.000000    62.720000     3.413000   5221.140000
# 75%    4691.500000    34.000000    75.220000     3.722000   9199.242500
# max    6255.000000    45.000000   100.140000     4.308000  88646.760000
#
#           Promotion2     Promotion3    Promotion4     Promotion5  \
# count    1592.000000    1885.000000   1819.000000    2115.000000
# mean     3308.125810    1462.535523   3465.952501    4518.993173
# std      9382.823804    9667.580258   6413.116294    6048.661908
# ...

# %%
df_train['Temperature'] = (df_train['Temperature']-32) / 1.8

# %%
df_test['Temperature'] = (df_test['Temperature']-32) / 1.8

# %%
df_train['Temperature'].describe()
# Out:
# count    6255.000000
# mean       15.910666
# std        10.346719
# min       -18.922222
# 25%         8.427778
# 50%        17.066667
# 75%        24.011111
# max        37.855556
# Name: Temperature, dtype: float64

# %%
def arrange_date_format(date):
    year = date[6:]
    month = date[3:5]
    day = date[:2]

    return year + '-' + month + '-' + day

# %%
df_train['Date'] = df_train['Date'].apply(arrange_date_format)
df_test['Date'] = df_test['Date'].apply(arrange_date_format)

# %%
import datetime

df_train['Date'] = pd.to_datetime(df_train['Date'])
df_test['Date'] = pd.to_datetime(df_test['Date'])

# %%
df_train
# Out:
#         id  Store       Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0        1      1 2010-02-05     5.727778       2.572         NaN         NaN
# 1        2      1 2010-02-12     3.616667       2.548         NaN         NaN
# 2        3      1 2010-02-19     4.405556       2.514         NaN         NaN
# 3        4      1 2010-02-26     8.127778       2.561         NaN         NaN
# 4        5      1 2010-03-05     8.055556       2.625         NaN         NaN
# ...    ...    ...        ...          ...         ...         ...         ...
# 6250  6251     45 2012-08-31    23.938889       3.867    23641.30        6.00
# 6251  6252     45 2012-09-07    24.277778       3.911    11024.45       12.80
# 6252  6253     45 2012-09-14    19.927778       3.948    11407.95         NaN
# 6253  6254     45 2012-09-21    18.511111       4.038     8452.20       92.28
# 6254  6255     45 2012-09-28    18.266667       3.997     4556.61       20.64
#
# ...

# %%
df_train['Month'] = df_train['Date'].dt.month
df_test['Month'] = df_test['Date'].dt.month

# %%
df_train.head()
# Out:
#    id  Store       Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0   1      1 2010-02-05     5.727778       2.572         NaN         NaN
# 1   2      1 2010-02-12     3.616667       2.548         NaN         NaN
# 2   3      1 2010-02-19     4.405556       2.514         NaN         NaN
# 3   4      1 2010-02-26     8.127778       2.561         NaN         NaN
# 4   5      1 2010-03-05     8.055556       2.625         NaN         NaN
#
#    Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  Weekly_Sales  \
# 0         NaN         NaN         NaN         8.106      False    1643690.90
# 1         NaN         NaN         NaN         8.106       True    1641957.44
# 2         NaN         NaN         NaN         8.106      False    1611968.17
# 3         NaN         NaN         NaN         8.106      False    1409727.59
# 4         NaN         NaN         NaN         8.106      False    1554806.68
#
#    Month
# 0      2
# 1      2
# 2      2
# 3      2
# 4      3

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6255 entries, 0 to 6254
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            6255 non-null   int64
#  1   Store         6255 non-null   int64
#  2   Date          6255 non-null   datetime64[ns]
#  3   Temperature   6255 non-null   float64
#  4   Fuel_Price    6255 non-null   float64
#  5   Promotion1    2102 non-null   float64
#  6   Promotion2    1592 non-null   float64
#  7   Promotion3    1885 non-null   float64
#  8   Promotion4    1819 non-null   float64
#  9   Promotion5    2115 non-null   float64
#  10  Unemployment  6255 non-null   float64
#  11  IsHoliday     6255 non-null   bool
#  12  Weekly_Sales  6255 non-null   float64
#  13  Month         6255 non-null   int64
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(3)
# memory usage: 641.5 KB

# %%
df_test.head()
# Out:
#    id  Store       Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0   1      1 2012-10-05    20.305556       3.617     8077.89         NaN
# 1   2      1 2012-10-12    17.216667       3.601     2086.18         NaN
# 2   3      1 2012-10-19    19.983333       3.594      950.33         NaN
# 3   4      1 2012-10-26    20.644444       3.506     2585.85       31.75
# 4   5      2 2012-10-05    21.261111       3.617     6037.76         NaN
#
#    Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  Month
# 0       18.22     3617.43     3626.14         6.573      False     10
# 1        8.11      602.36     5926.45         6.573      False     10
# 2        4.93       80.25     2312.85         6.573      False     10
# 3        6.00     1057.16     1305.01         6.573      False     10
# 4       10.04     3027.37     3853.40         6.170      False     10

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            180 non-null    int64
#  1   Store         180 non-null    int64
#  2   Date          180 non-null    datetime64[ns]
#  3   Temperature   180 non-null    float64
#  4   Fuel_Price    180 non-null    float64
#  5   Promotion1    178 non-null    float64
#  6   Promotion2    45 non-null     float64
#  7   Promotion3    161 non-null    float64
#  8   Promotion4    146 non-null    float64
#  9   Promotion5    180 non-null    float64
#  10  Unemployment  180 non-null    float64
#  11  IsHoliday     180 non-null    bool
#  12  Month         180 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(8), int64(3)
# memory usage: 17.2 KB

# %%
import matplotlib.pyplot as plt

plt.hist(df_train.Weekly_Sales, bins=50)
plt.show()

# %% [markdown]
# ---

# %%
df_train = df_train.fillna(0)

# %%
df_train
# Out:
#         id  Store       Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0        1      1 2010-02-05     5.727778       2.572        0.00        0.00
# 1        2      1 2010-02-12     3.616667       2.548        0.00        0.00
# 2        3      1 2010-02-19     4.405556       2.514        0.00        0.00
# 3        4      1 2010-02-26     8.127778       2.561        0.00        0.00
# 4        5      1 2010-03-05     8.055556       2.625        0.00        0.00
# ...    ...    ...        ...          ...         ...         ...         ...
# 6250  6251     45 2012-08-31    23.938889       3.867    23641.30        6.00
# 6251  6252     45 2012-09-07    24.277778       3.911    11024.45       12.80
# 6252  6253     45 2012-09-14    19.927778       3.948    11407.95        0.00
# 6253  6254     45 2012-09-21    18.511111       4.038     8452.20       92.28
# 6254  6255     45 2012-09-28    18.266667       3.997     4556.61       20.64
#
# ...

# %%
df_test = df_test.fillna(0)

# %%
df_test
# Out:
#       id  Store       Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0      1      1 2012-10-05    20.305556       3.617     8077.89        0.00
# 1      2      1 2012-10-12    17.216667       3.601     2086.18        0.00
# 2      3      1 2012-10-19    19.983333       3.594      950.33        0.00
# 3      4      1 2012-10-26    20.644444       3.506     2585.85       31.75
# 4      5      2 2012-10-05    21.261111       3.617     6037.76        0.00
# ..   ...    ...        ...          ...         ...         ...         ...
# 175  176     44 2012-10-26     8.316667       3.755       38.65        2.61
# 176  177     45 2012-10-05    18.272222       3.985     5046.74        0.00
# 177  178     45 2012-10-12    12.483333       4.000     1956.28        0.00
# 178  179     45 2012-10-19    13.594444       3.969     2004.02        0.00
# 179  180     45 2012-10-26    14.916667       3.882     4018.91       58.08
#
# ...

# %% [markdown]
# ---

# %%
df_train['Store'].nunique()
# Out:
# 45

# %%
df_train.head()
# Out:
#    id  Store       Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0   1      1 2010-02-05     5.727778       2.572         0.0         0.0
# 1   2      1 2010-02-12     3.616667       2.548         0.0         0.0
# 2   3      1 2010-02-19     4.405556       2.514         0.0         0.0
# 3   4      1 2010-02-26     8.127778       2.561         0.0         0.0
# 4   5      1 2010-03-05     8.055556       2.625         0.0         0.0
#
#    Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  Weekly_Sales  \
# 0         0.0         0.0         0.0         8.106      False    1643690.90
# 1         0.0         0.0         0.0         8.106       True    1641957.44
# 2         0.0         0.0         0.0         8.106      False    1611968.17
# 3         0.0         0.0         0.0         8.106      False    1409727.59
# 4         0.0         0.0         0.0         8.106      False    1554806.68
#
#    Month
# 0      2
# 1      2
# 2      2
# 3      2
# 4      3

# %%
df_train = df_train.sort_values(by=['Date'])
df_train.head()
# Out:
#         id  Store       Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0        1      1 2010-02-05     5.727778       2.572         0.0         0.0
# 5421  5422     40 2010-02-05    -9.733333       2.788         0.0         0.0
# 1529  1530     12 2010-02-05     9.705556       2.962         0.0         0.0
# 4726  4727     35 2010-02-05    -2.672222       2.784         0.0         0.0
# 2224  2225     17 2010-02-05    -4.938889       2.666         0.0         0.0
#
#       Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  \
# 0            0.0         0.0         0.0         8.106      False
# 5421         0.0         0.0         0.0         5.892      False
# 1529         0.0         0.0         0.0        13.975      False
# 4726         0.0         0.0         0.0         9.262      False
# 2224         0.0         0.0         0.0         6.548      False
#
#       Weekly_Sales  Month
# 0       1643690.90      2
# 5421    1001943.80      2
# ...

# %%
df_train['Date'].min(), df_train['Date'].max()
# Out:
# (Timestamp('2010-02-05 00:00:00'), Timestamp('2012-09-28 00:00:00'))

# %%
df_test['Date'].min(), df_test['Date'].max()
# Out:
# (Timestamp('2012-10-05 00:00:00'), Timestamp('2012-10-26 00:00:00'))

# %%
df_store1 = df_train[df_train['Store']==1].sort_values(by=['Date'])
df_store2 = df_train[df_train['Store']==2].sort_values(by=['Date'])
df_store3 = df_train[df_train['Store']==3].sort_values(by=['Date'])
df_store4 = df_train[df_train['Store']==4].sort_values(by=['Date'])
df_store5 = df_train[df_train['Store']==5].sort_values(by=['Date'])

df_store6 = df_train[df_train['Store']==6].sort_values(by=['Date'])
df_store7 = df_train[df_train['Store']==7].sort_values(by=['Date'])
df_store8 = df_train[df_train['Store']==8].sort_values(by=['Date'])
df_store9 = df_train[df_train['Store']==9].sort_values(by=['Date'])
df_store10 = df_train[df_train['Store']==10].sort_values(by=['Date'])

df_store11 = df_train[df_train['Store']==11].sort_values(by=['Date'])
df_store12 = df_train[df_train['Store']==12].sort_values(by=['Date'])
df_store13 = df_train[df_train['Store']==13].sort_values(by=['Date'])
df_store14 = df_train[df_train['Store']==14].sort_values(by=['Date'])
df_store15 = df_train[df_train['Store']==15].sort_values(by=['Date'])

df_store16 = df_train[df_train['Store']==16].sort_values(by=['Date'])
df_store17 = df_train[df_train['Store']==17].sort_values(by=['Date'])
df_store18 = df_train[df_train['Store']==18].sort_values(by=['Date'])
df_store19 = df_train[df_train['Store']==19].sort_values(by=['Date'])
df_store20 = df_train[df_train['Store']==20].sort_values(by=['Date'])

df_store21 = df_train[df_train['Store']==21].sort_values(by=['Date'])
df_store22 = df_train[df_train['Store']==22].sort_values(by=['Date'])
df_store23 = df_train[df_train['Store']==23].sort_values(by=['Date'])
df_store24 = df_train[df_train['Store']==24].sort_values(by=['Date'])
df_store25 = df_train[df_train['Store']==25].sort_values(by=['Date'])

df_store26 = df_train[df_train['Store']==26].sort_values(by=['Date'])
df_store27 = df_train[df_train['Store']==27].sort_values(by=['Date'])
df_store28 = df_train[df_train['Store']==28].sort_values(by=['Date'])
df_store29 = df_train[df_train['Store']==29].sort_values(by=['Date'])
df_store30 = df_train[df_train['Store']==30].sort_values(by=['Date'])

df_store31 = df_train[df_train['Store']==31].sort_values(by=['Date'])
df_store32 = df_train[df_train['Store']==32].sort_values(by=['Date'])
df_store33 = df_train[df_train['Store']==33].sort_values(by=['Date'])
df_store34 = df_train[df_train['Store']==34].sort_values(by=['Date'])
df_store35 = df_train[df_train['Store']==35].sort_values(by=['Date'])

df_store36 = df_train[df_train['Store']==36].sort_values(by=['Date'])
df_store37 = df_train[df_train['Store']==37].sort_values(by=['Date'])
df_store38 = df_train[df_train['Store']==38].sort_values(by=['Date'])
df_store39 = df_train[df_train['Store']==39].sort_values(by=['Date'])
df_store40 = df_train[df_train['Store']==40].sort_values(by=['Date'])

df_store41 = df_train[df_train['Store']==41].sort_values(by=['Date'])
df_store42 = df_train[df_train['Store']==42].sort_values(by=['Date'])
df_store43 = df_train[df_train['Store']==43].sort_values(by=['Date'])
df_store44 = df_train[df_train['Store']==44].sort_values(by=['Date'])
df_store45 = df_train[df_train['Store']==45].sort_values(by=['Date'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use(['dark_background'])

df_store1 = df_train[df_train['Store']==1].sort_values(by=['Date'])
plt.plot(df_store1['Date'], df_store1['Weekly_Sales'], label='Store1');
plt.gcf().set_size_inches(25, 6)

df_store2 = df_train[df_train['Store']==2].sort_values(by=['Date'])
plt.plot(df_store2['Date'], df_store2['Weekly_Sales'], label='Store2');
plt.gcf().set_size_inches(25, 6)

df_store3 = df_train[df_train['Store']==3].sort_values(by=['Date'])
plt.plot(df_store3['Date'], df_store3['Weekly_Sales'], label='Store3');
plt.gcf().set_size_inches(25, 6)

df_store4 = df_train[df_train['Store']==4].sort_values(by=['Date'])
plt.plot(df_store4['Date'], df_store4['Weekly_Sales'], label='Store4');
plt.gcf().set_size_inches(25, 6)

df_store5 = df_train[df_train['Store']==5].sort_values(by=['Date'])
plt.plot(df_store5['Date'], df_store5['Weekly_Sales'], label='Store5');
plt.gcf().set_size_inches(25, 6)

df_store6 = df_train[df_train['Store']==6].sort_values(by=['Date'])
plt.plot(df_store6['Date'], df_store6['Weekly_Sales'], label='Store6');
plt.gcf().set_size_inches(25, 6)

df_store7 = df_train[df_train['Store']==7].sort_values(by=['Date'])
plt.plot(df_store7['Date'], df_store7['Weekly_Sales'], label='Store7');
plt.gcf().set_size_inches(25, 6)

df_store8 = df_train[df_train['Store']==8].sort_values(by=['Date'])
plt.plot(df_store8['Date'], df_store8['Weekly_Sales'], label='Store8');
plt.gcf().set_size_inches(25, 6)

df_store9 = df_train[df_train['Store']==9].sort_values(by=['Date'])
plt.plot(df_store9['Date'], df_store9['Weekly_Sales'], label='Store9');
plt.gcf().set_size_inches(25, 6)

df_store10 = df_train[df_train['Store']==10].sort_values(by=['Date'])
plt.plot(df_store10['Date'], df_store10['Weekly_Sales'], label='Store10');
plt.gcf().set_size_inches(25, 6)

plt.legend()

# %%
df_store11 = df_train[df_train['Store']==11].sort_values(by=['Date'])
plt.plot(df_store11['Date'], df_store11['Weekly_Sales'], label='Store11');
plt.gcf().set_size_inches(25, 6)

df_store12 = df_train[df_train['Store']==12].sort_values(by=['Date'])
plt.plot(df_store12['Date'], df_store12['Weekly_Sales'], label='Store12');
plt.gcf().set_size_inches(25, 6)

df_store13 = df_train[df_train['Store']==13].sort_values(by=['Date'])
plt.plot(df_store13['Date'], df_store13['Weekly_Sales'], label='Store13');
plt.gcf().set_size_inches(25, 6)

df_store14 = df_train[df_train['Store']==14].sort_values(by=['Date'])
plt.plot(df_store14['Date'], df_store14['Weekly_Sales'], label='Store14');
plt.gcf().set_size_inches(25, 6)

df_store15 = df_train[df_train['Store']==15].sort_values(by=['Date'])
plt.plot(df_store15['Date'], df_store15['Weekly_Sales'], label='Store15');
plt.gcf().set_size_inches(25, 6)

df_store16 = df_train[df_train['Store']==16].sort_values(by=['Date'])
plt.plot(df_store16['Date'], df_store16['Weekly_Sales'], label='Store16');
plt.gcf().set_size_inches(25, 6)

df_store17 = df_train[df_train['Store']==17].sort_values(by=['Date'])
plt.plot(df_store17['Date'], df_store17['Weekly_Sales'], label='Store17');
plt.gcf().set_size_inches(25, 6)

df_store18 = df_train[df_train['Store']==18].sort_values(by=['Date'])
plt.plot(df_store18['Date'], df_store18['Weekly_Sales'], label='Store18');
plt.gcf().set_size_inches(25, 6)

df_store19 = df_train[df_train['Store']==19].sort_values(by=['Date'])
plt.plot(df_store19['Date'], df_store19['Weekly_Sales'], label='Store19');
plt.gcf().set_size_inches(25, 6)

df_store20 = df_train[df_train['Store']==20].sort_values(by=['Date'])
plt.plot(df_store20['Date'], df_store20['Weekly_Sales'], label='Store20');
plt.gcf().set_size_inches(25, 6)


plt.legend()

# %%
df_store21 = df_train[df_train['Store']==21].sort_values(by=['Date'])
plt.plot(df_store21['Date'], df_store21['Weekly_Sales'], label='Store21');
plt.gcf().set_size_inches(25, 6)

df_store22 = df_train[df_train['Store']==22].sort_values(by=['Date'])
plt.plot(df_store22['Date'], df_store22['Weekly_Sales'], label='Store22');
plt.gcf().set_size_inches(25, 6)

df_store23 = df_train[df_train['Store']==23].sort_values(by=['Date'])
plt.plot(df_store23['Date'], df_store23['Weekly_Sales'], label='Store23');
plt.gcf().set_size_inches(25, 6)

df_store24 = df_train[df_train['Store']==24].sort_values(by=['Date'])
plt.plot(df_store24['Date'], df_store24['Weekly_Sales'], label='Store24');
plt.gcf().set_size_inches(25, 6)

df_store25 = df_train[df_train['Store']==25].sort_values(by=['Date'])
plt.plot(df_store25['Date'], df_store25['Weekly_Sales'], label='Store25');
plt.gcf().set_size_inches(25, 6)

df_store26 = df_train[df_train['Store']==26].sort_values(by=['Date'])
plt.plot(df_store26['Date'], df_store26['Weekly_Sales'], label='Store26');
plt.gcf().set_size_inches(25, 6)

df_store27 = df_train[df_train['Store']==27].sort_values(by=['Date'])
plt.plot(df_store27['Date'], df_store27['Weekly_Sales'], label='Store27');
plt.gcf().set_size_inches(25, 6)

df_store28 = df_train[df_train['Store']==28].sort_values(by=['Date'])
plt.plot(df_store28['Date'], df_store28['Weekly_Sales'], label='Store28');
plt.gcf().set_size_inches(25, 6)

df_store29 = df_train[df_train['Store']==29].sort_values(by=['Date'])
plt.plot(df_store29['Date'], df_store29['Weekly_Sales'], label='Store29');
plt.gcf().set_size_inches(25, 6)

df_store30 = df_train[df_train['Store']==30].sort_values(by=['Date'])
plt.plot(df_store30['Date'], df_store30['Weekly_Sales'], label='Store30');
plt.gcf().set_size_inches(25, 6)


plt.legend()

# %%
df_store31 = df_train[df_train['Store']==31].sort_values(by=['Date'])
plt.plot(df_store31['Date'], df_store31['Weekly_Sales'], label='Store31');
plt.gcf().set_size_inches(25, 6)

df_store32 = df_train[df_train['Store']==32].sort_values(by=['Date'])
plt.plot(df_store32['Date'], df_store32['Weekly_Sales'], label='Store32');
plt.gcf().set_size_inches(25, 6)

df_store33 = df_train[df_train['Store']==33].sort_values(by=['Date'])
plt.plot(df_store33['Date'], df_store33['Weekly_Sales'], label='Store33');
plt.gcf().set_size_inches(25, 6)

df_store34 = df_train[df_train['Store']==34].sort_values(by=['Date'])
plt.plot(df_store34['Date'], df_store34['Weekly_Sales'], label='Store34');
plt.gcf().set_size_inches(25, 6)

df_store35 = df_train[df_train['Store']==35].sort_values(by=['Date'])
plt.plot(df_store35['Date'], df_store35['Weekly_Sales'], label='Store35');
plt.gcf().set_size_inches(25, 6)

df_store36 = df_train[df_train['Store']==36].sort_values(by=['Date'])
plt.plot(df_store36['Date'], df_store36['Weekly_Sales'], label='Store36');
plt.gcf().set_size_inches(25, 6)

df_store37 = df_train[df_train['Store']==37].sort_values(by=['Date'])
plt.plot(df_store37['Date'], df_store37['Weekly_Sales'], label='Store37');
plt.gcf().set_size_inches(25, 6)

df_store38 = df_train[df_train['Store']==38].sort_values(by=['Date'])
plt.plot(df_store38['Date'], df_store38['Weekly_Sales'], label='Store38');
plt.gcf().set_size_inches(25, 6)

df_store39 = df_train[df_train['Store']==39].sort_values(by=['Date'])
plt.plot(df_store39['Date'], df_store39['Weekly_Sales'], label='Store39');
plt.gcf().set_size_inches(25, 6)

df_store40 = df_train[df_train['Store']==40].sort_values(by=['Date'])
plt.plot(df_store40['Date'], df_store40['Weekly_Sales'], label='Store40');
plt.gcf().set_size_inches(25, 6)


plt.legend()

# %%
df_store41 = df_train[df_train['Store']==41].sort_values(by=['Date'])
plt.plot(df_store41['Date'], df_store41['Weekly_Sales'], label='Store41');
plt.gcf().set_size_inches(25, 6)

df_store42 = df_train[df_train['Store']==42].sort_values(by=['Date'])
plt.plot(df_store42['Date'], df_store42['Weekly_Sales'], label='Store42');
plt.gcf().set_size_inches(25, 6)

df_store43 = df_train[df_train['Store']==43].sort_values(by=['Date'])
plt.plot(df_store43['Date'], df_store43['Weekly_Sales'], label='Store43');
plt.gcf().set_size_inches(25, 6)

df_store44 = df_train[df_train['Store']==44].sort_values(by=['Date'])
plt.plot(df_store44['Date'], df_store44['Weekly_Sales'], label='Store44');
plt.gcf().set_size_inches(25, 6)

df_store45 = df_train[df_train['Store']==45].sort_values(by=['Date'])
plt.plot(df_store45['Date'], df_store45['Weekly_Sales'], label='Store45');
plt.gcf().set_size_inches(25, 6)

plt.legend()

# %%
df_concat = pd.DataFrame({'Date' : list(df_store1['Date']) , 
                          'Store1': list(df_store1['Weekly_Sales']),  
                          'Store2': list(df_store2['Weekly_Sales']), 
                          'Store3': list(df_store3['Weekly_Sales']),
                          'Store4': list(df_store4['Weekly_Sales']),
                          'Store5': list(df_store5['Weekly_Sales']),
                          'Store6': list(df_store6['Weekly_Sales']),
                          'Store7': list(df_store7['Weekly_Sales']),
                          'Store8': list(df_store8['Weekly_Sales']),
                          'Store9': list(df_store9['Weekly_Sales']),
                          'Store10': list(df_store10['Weekly_Sales']),
                          'Store11': list(df_store11['Weekly_Sales']),
                          'Store12': list(df_store12['Weekly_Sales']),
                          'Store13': list(df_store13['Weekly_Sales']),
                          'Store14': list(df_store14['Weekly_Sales']),
                          'Store15': list(df_store15['Weekly_Sales']),
                          'Store16': list(df_store16['Weekly_Sales']),
                          'Store17': list(df_store17['Weekly_Sales']),
                          'Store18': list(df_store18['Weekly_Sales']),
                          'Store19': list(df_store19['Weekly_Sales']),
                          'Store20': list(df_store20['Weekly_Sales']),
                          'Store21': list(df_store21['Weekly_Sales']),
                          'Store22': list(df_store22['Weekly_Sales']),
                          'Store23': list(df_store23['Weekly_Sales']),
                          'Store24': list(df_store24['Weekly_Sales']),
                          'Store25': list(df_store25['Weekly_Sales']),
                          'Store26': list(df_store26['Weekly_Sales']),
                          'Store27': list(df_store27['Weekly_Sales']),
                          'Store28': list(df_store28['Weekly_Sales']),
                          'Store29': list(df_store29['Weekly_Sales']),
                          'Store30': list(df_store30['Weekly_Sales']),
                          'Store31': list(df_store31['Weekly_Sales']),
                          'Store32': list(df_store32['Weekly_Sales']),
                          'Store33': list(df_store33['Weekly_Sales']),
                          'Store34': list(df_store34['Weekly_Sales']),
                          'Store35': list(df_store35['Weekly_Sales']),
                          'Store36': list(df_store36['Weekly_Sales']),
                          'Store37': list(df_store37['Weekly_Sales']),
                          'Store38': list(df_store38['Weekly_Sales']),
                          'Store39': list(df_store39['Weekly_Sales']),
                          'Store40': list(df_store40['Weekly_Sales']),
                          'Store41': list(df_store41['Weekly_Sales']),
                          'Store42': list(df_store42['Weekly_Sales']),
                          'Store43': list(df_store43['Weekly_Sales']),
                          'Store44': list(df_store44['Weekly_Sales']),
                          'Store45': list(df_store45['Weekly_Sales'])    
                         })

df_concat
# Out:
#           Date     Store1     Store2    Store3     Store4    Store5  \
# 0   2010-02-05 1643690.90 2136989.46 461622.22 2135143.87 317173.10
# 1   2010-02-12 1641957.44 2137809.50 420728.96 2188307.39 311825.70
# 2   2010-02-19 1611968.17 2124451.54 421642.19 2049860.26 303447.57
# 3   2010-02-26 1409727.59 1865097.27 407204.86 1925728.84 270281.63
# 4   2010-03-05 1554806.68 1991013.13 415202.04 1971057.44 288855.71
# ..         ...        ...        ...       ...        ...       ...
# 134 2012-08-31 1582083.40 1947083.30 408838.73 2081181.35 344642.01
# 135 2012-09-07 1661767.33 1898777.07 408229.73 2125104.72 350648.91
# 136 2012-09-14 1517428.87 1814806.63 407589.16 2117854.60 299800.67
# 137 2012-09-21 1506126.06 1829415.67 414392.09 2119438.53 307306.76
# 138 2012-09-28 1437059.26 1746470.56 389813.02 2027620.23 310141.68
#
#         Store6    Store7     Store8    Store9  ...   Store36   Store37  \
# 0   1652635.10 496725.44 1004137.09 549505.55  ... 467546.74 536006.73
# ...

# %% [markdown]
# ---

# %%
df_store1.head()
# Out:
#    id  Store       Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0   1      1 2010-02-05     5.727778       2.572         0.0         0.0
# 1   2      1 2010-02-12     3.616667       2.548         0.0         0.0
# 2   3      1 2010-02-19     4.405556       2.514         0.0         0.0
# 3   4      1 2010-02-26     8.127778       2.561         0.0         0.0
# 4   5      1 2010-03-05     8.055556       2.625         0.0         0.0
#
#    Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  Weekly_Sales  \
# 0         0.0         0.0         0.0         8.106      False    1643690.90
# 1         0.0         0.0         0.0         8.106       True    1641957.44
# 2         0.0         0.0         0.0         8.106      False    1611968.17
# 3         0.0         0.0         0.0         8.106      False    1409727.59
# 4         0.0         0.0         0.0         8.106      False    1554806.68
#
#    Month
# 0      2
# 1      2
# 2      2
# 3      2
# 4      3

# %%
df_train.groupby('IsHoliday')['Weekly_Sales'].mean()
# Out:
# IsHoliday
# False    1.041784e+06
# True     1.122888e+06
# Name: Weekly_Sales, dtype: float64

# %%
fig, ax1 = plt.subplots()
ax1.plot(df_store1['Date'], df_store1['Weekly_Sales'], color='green', label='WeeklySales')

ax2 = ax1.twinx()
ax2.plot(df_store1['Date'], df_store1['Temperature'], color='deeppink', label='Temp')

plt.gcf().set_size_inches(25, 6)
fig.legend()
plt.show()

# %%
fig, ax1 = plt.subplots()
ax1.plot(df_store1['Date'], df_store1['Weekly_Sales'], color='green', label= 'WeeklySales')

ax2 = ax1.twinx()
ax2.plot(df_store1['Date'], df_store1['Fuel_Price'], color='deeppink', label='Fuel')

plt.gcf().set_size_inches(25, 6)
fig.legend()
plt.show()

# %%
fig, ax1 = plt.subplots()
ax1.plot(df_store1['Date'], df_store1['Weekly_Sales'], color='green', label='WS')

ax2 = ax1.twinx()
ax2.plot(df_store1['Date'], df_store1['Unemployment'], color='deeppink',label='Unemploy')

plt.gcf().set_size_inches(25, 6)
fig.legend()
plt.show()

# %%
fig, ax1 = plt.subplots()
ax1.plot(df_store1['Date'], df_store1['Promotion1'], color='green', label='Promotion1')

ax2 = ax1.twinx()
ax2.plot(df_store1['Date'], df_store1['Promotion2'], color='deeppink',label='Promotion2')

ax3 = ax1.twinx()
ax3.plot(df_store1['Date'], df_store1['Promotion3'], color='olive',label='Promotion3')

ax4 = ax1.twinx()
ax4.plot(df_store1['Date'], df_store1['Promotion4'], color='cyan',label='Promotion4')

ax5 = ax1.twinx()
ax5.plot(df_store1['Date'], df_store1['Promotion5'], color='violet',label='Promotion5')

plt.gcf().set_size_inches(25, 6)
fig.legend()
plt.show()

# %%
df_store1.head(5)
# Out:
#    id  Store       Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0   1      1 2010-02-05     5.727778       2.572         0.0         0.0
# 1   2      1 2010-02-12     3.616667       2.548         0.0         0.0
# 2   3      1 2010-02-19     4.405556       2.514         0.0         0.0
# 3   4      1 2010-02-26     8.127778       2.561         0.0         0.0
# 4   5      1 2010-03-05     8.055556       2.625         0.0         0.0
#
#    Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  Weekly_Sales  \
# 0         0.0         0.0         0.0         8.106      False    1643690.90
# 1         0.0         0.0         0.0         8.106       True    1641957.44
# 2         0.0         0.0         0.0         8.106      False    1611968.17
# 3         0.0         0.0         0.0         8.106      False    1409727.59
# 4         0.0         0.0         0.0         8.106      False    1554806.68
#
#    Month
# 0      2
# 1      2
# 2      2
# 3      2
# 4      3

# %%
df_corr = df_store1.drop(['Store', 'IsHoliday', 'Date'], axis=1)
df_corr.corr()
# Out:
#                     id  Temperature  Fuel_Price  Promotion1  Promotion2  \
# id            1.000000     0.164865    0.781312    0.611159    0.160487
# Temperature   0.164865     1.000000    0.233203    0.007139   -0.253376
# Fuel_Price    0.781312     0.233203    1.000000    0.361256    0.030328
# Promotion1    0.611159     0.007139    0.361256    1.000000    0.181658
# Promotion2    0.160487    -0.253376    0.030328    0.181658    1.000000
# Promotion3    0.060563    -0.053737    0.007260   -0.031473   -0.010224
# Promotion4    0.389980    -0.014340    0.222323    0.805282    0.105535
# Promotion5    0.619656    -0.137854    0.320325    0.599043    0.240530
# Unemployment -0.775465    -0.210690   -0.509928   -0.651054   -0.048483
# Weekly_Sales  0.222847    -0.223121    0.124382    0.239741    0.013590
# Month         0.098234     0.253505   -0.131586   -0.088418   -0.014029
#
#               Promotion3  Promotion4  Promotion5  Unemployment  Weekly_Sales  \
# ...

# %%
df_corr = df_store1.drop(['Store', 'IsHoliday', 'Date'], axis=1)

sns.heatmap(df_corr.corr(), vmin = -1, vmax = +1, annot = True, cmap = 'coolwarm');
plt.gcf().set_size_inches(10, 10)

# %%
sns.scatterplot(x='Unemployment', y='Weekly_Sales', data=df_store1);
plt.gcf().set_size_inches(7, 7)

# %%
df_store1.head(5)
# Out:
#    id  Store       Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0   1      1 2010-02-05     5.727778       2.572         0.0         0.0
# 1   2      1 2010-02-12     3.616667       2.548         0.0         0.0
# 2   3      1 2010-02-19     4.405556       2.514         0.0         0.0
# 3   4      1 2010-02-26     8.127778       2.561         0.0         0.0
# 4   5      1 2010-03-05     8.055556       2.625         0.0         0.0
#
#    Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  Weekly_Sales  \
# 0         0.0         0.0         0.0         8.106      False    1643690.90
# 1         0.0         0.0         0.0         8.106       True    1641957.44
# 2         0.0         0.0         0.0         8.106      False    1611968.17
# 3         0.0         0.0         0.0         8.106      False    1409727.59
# 4         0.0         0.0         0.0         8.106      False    1554806.68
#
#    Month
# 0      2
# 1      2
# 2      2
# 3      2
# 4      3

# %%
df_store1['Dayofweek'] = df_store1['Date'].dt.dayofweek
df_store1['month'] = df_store1['Date'].dt.month
df_store1.head(5)
# Out:
#    id  Store       Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0   1      1 2010-02-05     5.727778       2.572         0.0         0.0
# 1   2      1 2010-02-12     3.616667       2.548         0.0         0.0
# 2   3      1 2010-02-19     4.405556       2.514         0.0         0.0
# 3   4      1 2010-02-26     8.127778       2.561         0.0         0.0
# 4   5      1 2010-03-05     8.055556       2.625         0.0         0.0
#
#    Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  Weekly_Sales  \
# 0         0.0         0.0         0.0         8.106      False    1643690.90
# 1         0.0         0.0         0.0         8.106       True    1641957.44
# 2         0.0         0.0         0.0         8.106      False    1611968.17
# 3         0.0         0.0         0.0         8.106      False    1409727.59
# 4         0.0         0.0         0.0         8.106      False    1554806.68
#
#    Month  Dayofweek  month
# 0      2          4      2
# ...

# %%
len(df_store1)
# Out:
# 139

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

X=df_store1.drop(['id', 'Date', 'IsHoliday', 'Weekly_Sales'], axis=1)
Y=df_store1['Weekly_Sales']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.4, random_state=1239)

print(x_train.shape)
print(y_train.shape)

print(x_test.shape)
print(y_test.shape)
# Out:
# (83, 12)
# (83,)
# (56, 12)
# (56,)

# %%
x_train.head()
# Out:
#      Store  Temperature  Fuel_Price  Promotion1  Promotion2  Promotion3  \
# 7        1    10.805556       2.732        0.00        0.00         0.0
# 40       1    15.338889       2.728        0.00        0.00         0.0
# 85       1    24.333333       3.467        0.00        0.00         0.0
# 100      1     9.450000       3.157     6277.39    21813.16       143.1
# 37       1    21.033333       2.725        0.00        0.00         0.0
#
#      Promotion4  Promotion5  Unemployment  Month  Dayofweek  month
# 7          0.00         0.0         8.106      3          4      3
# 40         0.00         0.0         7.838     11          4     11
# 85         0.00         0.0         7.962      9          4      9
# 100     1450.13      8483.0         7.348      1          4      1
# 37         0.00         0.0         7.838     10          4     10

# %%
x_test.head()
# Out:
#      Store  Temperature  Fuel_Price  Promotion1  Promotion2  Promotion3  \
# 118      1    23.205556       3.688     8351.40         0.0       10.52
# 4        1     8.055556       2.625        0.00         0.0        0.00
# 97       1    10.905556       3.159     5011.32        67.0      347.37
# 86       1    26.494444       3.355        0.00         0.0        0.00
# 34       1    22.161111       2.603        0.00         0.0        0.00
#
#      Promotion4  Promotion5  Unemployment  Month  Dayofweek  month
# 118     2443.14     3127.88         7.143      5          4      5
# 4          0.00        0.00         8.106      3          4      3
# 97       225.79     4011.37         7.866     12          4     12
# 86         0.00        0.00         7.962      9          4      9
# 34         0.00        0.00         7.838     10          4     10

# %%
rfr = RandomForestRegressor(n_estimators=500, max_depth=4, random_state=1239)
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=4, n_estimators=500, random_state=1239)

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score
y_pred_train = rfr.predict(x_train)
y_pred_test = rfr.predict(x_test)


mae_train = mean_absolute_error(y_train, y_pred_train)
print('mae_train(mae): ', mae_train)
r2_train = r2_score(y_train, y_pred_train)
print('r2_score(r2): ', r2_train)
print('')
mae_test = mean_absolute_error(y_test, y_pred_test)
print('mae_test(mae): ', mae_test)
r2_test = r2_score(y_test, y_pred_test)
print('r2_score(r2): ', r2_test)
# Out:
# mae_train(mae):  59586.497923498995
# r2_score(r2):  0.7153751943376845
#
# mae_test(mae):  104838.4543300463
# r2_score(r2):  0.21441887887296185

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression


poly = PolynomialFeatures(degree=2, include_bias=True)

X_train_poly = poly.fit_transform(x_train)

lin_reg = LinearRegression()
lin_reg.fit(X_train_poly, y_train)

X_test_poly = poly.transform(x_test)

y_pred_test = lin_reg.predict(X_test_poly)


mae_test = mean_absolute_error(y_test, y_pred_test)
print('mae_test(mae): ', mae_test)

r2_test = r2_score(y_test, y_pred_test)
print('r2_score(r2): ', r2_test)
# Out:
# mae_test(mae):  4960698810965.195
# r2_score(r2):  -9996391513899896.0

# %%
pd.options.display.float_format = '{:.2f}'.format

result = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred_test})
result['diff'] = result['Real Values'] - result['Predicted Values']
result.head(5)
# Out:
#      Real Values  Predicted Values               diff
# 118   1611096.05  2095986564820.66  -2095984953724.61
# 4     1554806.68        1300134.14          254672.54
# 97    1881176.67 10653924383983.93 -10653922502807.26
# 86    1394561.83        1483233.79          -88671.96
# 34    1453329.50        1504442.46          -51112.96

# %%
sns.scatterplot(result['Real Values'], result['Predicted Values'])
plt.xlim(1400000, 2000000)
plt.ylim(1400000, 2000000)

x = [1400000, 2000000]
y = [1400000, 2000000]
plt.plot(x, y, color='red')

plt.gcf().set_size_inches(8 ,8)
# Out:
# /Users/jade/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
result = result.reset_index(drop=True)

plt.plot(result.index, result['Real Values'], label='Real');
plt.plot(result.index, result['Predicted Values'], label='Pred');
plt.legend()
plt.gcf().set_size_inches(25, 6)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use(['dark_background'])

ftr_importances_values = rfr.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index = x_train.columns)
ftr_top20 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))
plt.title('Feature Importances')
sns.barplot(x=ftr_top20, y=ftr_top20.index)
plt.show()

# %%
df_store1.groupby('Dayofweek')['Weekly_Sales'].mean().sort_values(ascending=False)
# Out:
# Dayofweek
# 4   1555087.92
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# ---

# %%
df_test.head()
# Out:
#    id  Store       Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0   1      1 2012-10-05        20.31        3.62     8077.89        0.00
# 1   2      1 2012-10-12        17.22        3.60     2086.18        0.00
# 2   3      1 2012-10-19        19.98        3.59      950.33        0.00
# 3   4      1 2012-10-26        20.64        3.51     2585.85       31.75
# 4   5      2 2012-10-05        21.26        3.62     6037.76        0.00
#
#    Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  Month
# 0       18.22     3617.43     3626.14          6.57      False     10
# 1        8.11      602.36     5926.45          6.57      False     10
# 2        4.93       80.25     2312.85          6.57      False     10
# 3        6.00     1057.16     1305.01          6.57      False     10
# 4       10.04     3027.37     3853.40          6.17      False     10

# %%
df_test['Dayofweek'] = df_test['Date'].dt.dayofweek
df_test['month'] = df_test['Date'].dt.month

# %%
df_test.head()
# Out:
#    id  Store       Date  Temperature  Fuel_Price  Promotion1  Promotion2  \
# 0   1      1 2012-10-05        20.31        3.62     8077.89        0.00
# 1   2      1 2012-10-12        17.22        3.60     2086.18        0.00
# 2   3      1 2012-10-19        19.98        3.59      950.33        0.00
# 3   4      1 2012-10-26        20.64        3.51     2585.85       31.75
# 4   5      2 2012-10-05        21.26        3.62     6037.76        0.00
#
#    Promotion3  Promotion4  Promotion5  Unemployment  IsHoliday  Month  \
# 0       18.22     3617.43     3626.14          6.57      False     10
# 1        8.11      602.36     5926.45          6.57      False     10
# 2        4.93       80.25     2312.85          6.57      False     10
# 3        6.00     1057.16     1305.01          6.57      False     10
# 4       10.04     3027.37     3853.40          6.17      False     10
#
#    Dayofweek  month
# 0          4     10
# 1          4     10
# 2          4     10
# ...

# %%
df_test_ = df_test.drop(['id', 'Date', 'IsHoliday'], axis=1).copy()

# %%
prediction = rfr.predict(df_test_)

# %%
df_submission['Weekly_Sales'] = prediction

# %%
df_submission
# Out:
#       id  Weekly_Sales
# 0      1    1573139.16
# 1      2    1539935.19
# 2      3    1530391.33
# 3      4    1528007.43
# 4      5    1543851.87
# ..   ...           ...
# 175  176    1546041.82
# 176  177    1539997.07
# 177  178    1531678.85
# 178  179    1528229.29
# 179  180    1573532.43
#
# [180 rows x 2 columns]
